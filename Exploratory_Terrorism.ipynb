# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("globalterrorismdb_0718dist.csv",encoding='latin1')
# Out:
# <ipython-input-2-046621cb27a0>:1: DtypeWarning: Columns (4,31,33,76,94,96) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("globalterrorismdb_0718dist.csv",encoding='latin1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0      0.0       0.0      0.0     0.0      NaN
# 1      0.0       1.0      1.0     1.0      NaN
# 2     -9.0      -9.0      1.0     1.0      NaN
# 3     -9.0      -9.0      1.0     1.0      NaN
# 4     -9.0      -9.0      1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %%
df.shape
# Out:
# (5096, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5096 entries, 0 to 5095
# Columns: 135 entries, eventid to related
# dtypes: float64(64), int64(17), object(54)
# memory usage: 5.2+ MB

# %%
df.describe()
# Out:
#             eventid        iyear       imonth         iday     extended  \
# count  5.096000e+03  5096.000000  5096.000000  5096.000000  5096.000000
# mean   1.973872e+11  1973.809066     6.158359    15.303375     0.030808
# std    2.335571e+08     2.337862     3.293888     9.140459     0.172815
# min    1.970000e+11  1970.000000     0.000000     0.000000     0.000000
# 25%    1.972051e+11  1972.000000     3.000000     7.000000     0.000000
# 50%    1.974092e+11  1974.000000     6.000000    15.000000     0.000000
# 75%    1.976052e+11  1976.000000     9.000000    23.000000     0.000000
# max    1.977073e+11  1977.000000    12.000000    31.000000     1.000000
#
#            country       region     latitude    longitude  specificity  ...  \
# count  5096.000000  5096.000000  5006.000000  5006.000000  5096.000000  ...
# mean    271.445840     5.754513    36.559454   -26.458558     1.098705  ...
# std     204.761573     3.378390    22.836022    51.475161     0.594603  ...
# min       4.000000     1.000000   -43.532054  -157.818968     1.000000  ...
# 25%      98.000000     1.000000    35.800916   -73.931351     1.000000  ...
# 50%     217.000000     8.000000    41.400635    -5.956210     1.000000  ...
# 75%     362.000000     8.000000    52.501530     7.519113     1.000000  ...
# max     605.000000    12.000000    59.332788   172.636225     5.000000  ...
#
#           ransomamt  ransomamtus    ransompaid  ransompaidus  hostkidoutcome  \
# count  1.500000e+02          1.0  5.000000e+01           0.0      240.000000
# mean   1.383369e+06      20000.0  1.966980e+06           NaN        2.816667
# std    5.623556e+06          NaN  6.206763e+06           NaN        1.296815
# min    0.000000e+00      20000.0  0.000000e+00           NaN        2.000000
# 25%    0.000000e+00      20000.0  1.625000e+04           NaN        2.000000
# 50%    2.000000e+04      20000.0  1.000000e+05           NaN        2.000000
# 75%    5.907500e+05      20000.0  1.112500e+06           NaN        4.000000
# max    6.100000e+07      20000.0  4.100000e+07           NaN        7.000000
#
#         nreleased      INT_LOG     INT_IDEO     INT_MISC      INT_ANY
# count  177.000000  5095.000000  5095.000000  5095.000000  5095.000000
# mean     8.327684    -3.113052    -3.045535     0.494014    -1.288322
# std     30.232902     4.426756     4.488904     0.717657     3.985630
# min    -99.000000    -9.000000    -9.000000    -9.000000    -9.000000
# 25%      1.000000    -9.000000    -9.000000     0.000000     0.000000
# 50%      1.000000     0.000000     0.000000     1.000000     1.000000
# 75%      2.000000     0.000000     0.000000     1.000000     1.000000
# max    187.000000     1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 81 columns]

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
#        'gname3', 'gsubname3', 'motive', 'guncertain1', 'guncertain2',
#        'guncertain3', 'individual', 'nperps', 'nperpcap', 'claimed',
#        'claimmode', 'claimmode_txt', 'claim2', 'claimmode2',
#        'claimmode2_txt', 'claim3', 'claimmode3', 'claimmode3_txt',
#        'compclaim', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weaptype2', 'weaptype2_txt', 'weapsubtype2',
#        'weapsubtype2_txt', 'weaptype3', 'weaptype3_txt', 'weapsubtype3',
#        'weapsubtype3_txt', 'weaptype4', 'weaptype4_txt', 'weapsubtype4',
#        'weapsubtype4_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid',
#        'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'divert',
#        'kidhijcountry', 'ransom', 'ransomamt', 'ransomamtus',
#        'ransompaid', 'ransompaidus', 'ransomnote', 'hostkidoutcome',
#        'hostkidoutcome_txt', 'nreleased', 'addnotes', 'scite1', 'scite2',
#        'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC', 'INT_ANY',
#        'related'], dtype=object)

# %%
df=df[['iyear','imonth','iday','country_txt','city','region_txt','latitude','longitude','extended','target1','success','suicide','attacktype1_txt','targtype1_txt','gname','weaptype1_txt','nkill','nwound']]

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'region','attacktype1_txt':'AttackType','target1':'Target',
                  'nkill':'Killed','nwound':'Wounded',
                   'targtype1_txt':'Target_Type','gname':'group_name','weaptype1_txt':'Weapon_type','motive':'Motive',
                  'extended':'Extended','latitude':'Latitude','longitude':'Longitude', 'target1': 'Target','city':'City'}, inplace = True)

# %%
df.head()
# Out:
#    Year  Month  Day             Country           City  \
# 0  1970      7    2  Dominican Republic  Santo Domingo
# 1  1970      0    0              Mexico    Mexico city
# 2  1970      1    0         Philippines        Unknown
# 3  1970      1    0              Greece         Athens
# 4  1970      1    0               Japan        Fukouka
#
#                         region   Latitude   Longitude  Extended  \
# 0  Central America & Caribbean  18.456792  -69.951164         0
# 1                North America  19.371887  -99.086624         0
# 2               Southeast Asia  15.478598  120.599741         0
# 3               Western Europe  37.997490   23.762728         0
# 4                    East Asia  33.580412  130.396361         0
#
#                     Target  success  suicide                      AttackType  \
# 0             Julio Guzman        1        0                   Assassination
# 1  Nadine Chaval, daughter        1        0     Hostage Taking (Kidnapping)
# 2                 Employee        1        0                   Assassination
# 3             U.S. Embassy        1        0               Bombing/Explosion
# 4           U.S. Consulate        1        0  Facility/Infrastructure Attack
#
#                    Target_Type                          group_name  \
# 0  Private Citizens & Property                              MANO-D
# 1      Government (Diplomatic)  23rd of September Communist League
# 2          Journalists & Media                             Unknown
# 3      Government (Diplomatic)                             Unknown
# 4      Government (Diplomatic)                             Unknown
#
#   Weapon_type  Killed  Wounded
# 0     Unknown     1.0      0.0
# 1     Unknown     0.0      0.0
# 2     Unknown     1.0      0.0
# 3  Explosives     NaN      NaN
# 4  Incendiary     NaN      NaN

# %%
df.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# Country           0
# City              0
# region            0
# Latitude         90
# Longitude        90
# Extended          0
# Target           57
# success           0
# suicide           0
# AttackType        0
# Target_Type       1
# group_name        1
# Weapon_type       1
# Killed          612
# Wounded        1788
# dtype: int64

# %%
df['Latitude']=df['Latitude'].fillna(df['Latitude'].mean())
df['Longitude']=df['Longitude'].fillna(df['Longitude'].mean())
df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)
df['Target']=df["Target"].fillna(0)

# %%
df.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# City           0
# region         0
# Latitude       0
# Longitude      0
# Extended       0
# Target         0
# success        0
# suicide        0
# AttackType     0
# Target_Type    1
# group_name     1
# Weapon_type    1
# Killed         0
# Wounded        0
# dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-14-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                Year     Month       Day  Latitude  Longitude  Extended  \
# Year       1.000000 -0.077225 -0.007594  0.031909   0.310973 -0.015557
# Month     -0.077225  1.000000  0.035738 -0.002457   0.049528  0.012805
# Day       -0.007594  0.035738  1.000000 -0.016566   0.001776  0.012098
# Latitude   0.031909 -0.002457 -0.016566  1.000000   0.256971 -0.173448
# Longitude  0.310973  0.049528  0.001776  0.256971   1.000000  0.009936
# Extended  -0.015557  0.012805  0.012098 -0.173448   0.009936  1.000000
# success    0.099336  0.001889 -0.026055  0.018981   0.068549  0.056012
# suicide         NaN       NaN       NaN       NaN        NaN       NaN
# Killed     0.012154  0.034251  0.005323 -0.001600   0.074934 -0.007739
# Wounded    0.012992  0.029879 -0.013855  0.000060   0.049676 -0.003157
#
#             success  suicide    Killed   Wounded
# Year       0.099336      NaN  0.012154  0.012992
# Month      0.001889      NaN  0.034251  0.029879
# Day       -0.026055      NaN  0.005323 -0.013855
# Latitude   0.018981      NaN -0.001600  0.000060
# Longitude  0.068549      NaN  0.074934  0.049676
# Extended   0.056012      NaN -0.007739 -0.003157
# success    1.000000      NaN  0.053775  0.023300
# suicide         NaN      NaN       NaN       NaN
# Killed     0.053775      NaN  1.000000  0.166755
# Wounded    0.023300      NaN  0.166755  1.000000

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True, linewidths=0.5, fmt= '.3f')
# Out:
# <ipython-input-15-de6a4b2e2fc4>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, linewidths=0.5, fmt= '.3f')
# <Axes: >

# %%
df["Total_affected"]=df["Killed"]+df["Wounded"]

# %%
df.head()
# Out:
#    Year  Month  Day             Country           City  \
# 0  1970      7    2  Dominican Republic  Santo Domingo
# 1  1970      0    0              Mexico    Mexico city
# 2  1970      1    0         Philippines        Unknown
# 3  1970      1    0              Greece         Athens
# 4  1970      1    0               Japan        Fukouka
#
#                         region   Latitude   Longitude  Extended  \
# 0  Central America & Caribbean  18.456792  -69.951164         0
# 1                North America  19.371887  -99.086624         0
# 2               Southeast Asia  15.478598  120.599741         0
# 3               Western Europe  37.997490   23.762728         0
# 4                    East Asia  33.580412  130.396361         0
#
#                     Target  success  suicide                      AttackType  \
# 0             Julio Guzman        1        0                   Assassination
# 1  Nadine Chaval, daughter        1        0     Hostage Taking (Kidnapping)
# 2                 Employee        1        0                   Assassination
# 3             U.S. Embassy        1        0               Bombing/Explosion
# 4           U.S. Consulate        1        0  Facility/Infrastructure Attack
#
#                    Target_Type                          group_name  \
# 0  Private Citizens & Property                              MANO-D
# 1      Government (Diplomatic)  23rd of September Communist League
# 2          Journalists & Media                             Unknown
# 3      Government (Diplomatic)                             Unknown
# 4      Government (Diplomatic)                             Unknown
#
#   Weapon_type  Killed  Wounded  Total_affected
# 0     Unknown     1.0      0.0             1.0
# 1     Unknown     0.0      0.0             0.0
# 2     Unknown     1.0      0.0             1.0
# 3  Explosives     0.0      0.0             0.0
# 4  Incendiary     0.0      0.0             0.0

# %%
years = pd.DataFrame(df["Year"].value_counts())
years.head(10)
# Out:
#       Year
# 1976   923
# 1975   740
# 1977   689
# 1970   651
# 1974   581
# 1972   568
# 1973   473
# 1971   471

# %%
plt.subplots(figsize=(20,10))
year_counts = df['Year'].value_counts()[:10]
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.title('Attacks In Years',fontsize =30)
plt.xlabel('Year',fontsize =20)
plt.ylabel('No. of Attacks in Each Year',fontsize =20)
plt.xticks(fontsize=15,rotation = 90)
plt.show()

# %%
year_s=df[["Year",'Killed']].groupby("Year").sum().sort_values (by = 'Killed',ascending=False)
year_s.head(10)
# Out:
#       Killed
# Year
# 1976   674.0
# 1975   617.0
# 1972   566.0
# 1974   539.0
# 1973   370.0
# 1977   187.0
# 1970   174.0
# 1971   173.0

# %%
plt.subplots(figsize=(20,10))
year_counts = df['Killed'].value_counts()[:10]
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.title('no. of killed person In each Years',fontsize =30)
plt.xlabel('Year',fontsize =20)
plt.ylabel('No. of killed person',fontsize =20)
plt.xticks(fontsize=15,rotation = 90)
plt.show()

# %%
country = pd.DataFrame(df["Country"].value_counts())
print(" Name of the Countries (most affected by the attacks) : \n")
country.head(10)
# Out:
#  Name of the Countries (most affected by the attacks) :
#                     Country
# United States          1259
# United Kingdom         1245
# Italy                   368
# Spain                   345
# Argentina               279
# West Germany (FRG)      225
# Turkey                  222
# France                  178
# Greece                   82
# Iran                     67

# %%
plt.subplots(figsize=(20,10))
year_counts = df['Country'].value_counts()[:10]
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.title('Top Countries Affected',fontsize =30)
plt.xlabel('Countries Name',fontsize =20)
plt.ylabel('No. of Attacks(value_Count)',fontsize =20)
plt.xticks(fontsize=15,rotation = 90)
plt.show()

# %%
region = pd.DataFrame(df["region"].value_counts())
print("Regions affected most by the attacks: \n")
region.head()
# Out:
# Regions affected most by the attacks:
#                              region
# Western Europe                 2578
# North America                  1327
# South America                   472
# Middle East & North Africa      428
# Central America & Caribbean      99

# %%
plt.subplots(figsize=(20,10))
year_counts = df['region'].value_counts()[:10]
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.title('Terrorist Activities in Region',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("region",fontsize=20)
plt.xticks(fontsize=15,rotation = 90)
plt.show()

# %%
City= pd.DataFrame(df['City'].value_counts().drop("Unknown"))
print(" Name of the City (most affected by the attacks) : \n")
City.head(10)
# Out:
#  Name of the City (most affected by the attacks) :
#                City
# Belfast         637
# New York City   282
# Buenos Aires    163
# Rome            132
# Paris           109
# Madrid          101
# San Francisco    82
# London           80
# Ankara           80
# Athens           72

# %%
plt.subplots(figsize=(20,10))
year_counts = df['City'].value_counts()[:10]
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.title('Top City Affected',fontsize =30)
plt.xlabel('Cities Name',fontsize =20)
plt.ylabel('No. of Attacks (value_Count)',fontsize =20)
plt.xticks(fontsize=15,rotation = 90)
plt.show()

# %%
attacks = pd.DataFrame(df["AttackType"].value_counts())
attacks
# Out:
#                                      AttackType
# Bombing/Explosion                          2308
# Assassination                              1141
# Armed Assault                               642
# Facility/Infrastructure Attack              615
# Hostage Taking (Kidnapping)                 256
# Hijacking                                    48
# Hostage Taking (Barricade Incident)          44
# Unknown                                      28
# Unarmed Assault                              13
# Hostage Taking (Kid                           1

# %%
plt.subplots(figsize=(15,6))
year_counts = df['AttackType'].value_counts()[:10]
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.title("Types of Attacks",fontsize= 20)
plt.xlabel("Attack Types",fontsize=20)
plt.xticks(fontsize=15,rotation = 90)
plt.ylabel("No. of Attacks",fontsize=20)
plt.show()

# %%
target = pd.DataFrame(df['Target_Type'].value_counts())
target
# Out:
#                                 Target_Type
# Business                               1201
# Private Citizens & Property             905
# Military                                678
# Government (Diplomatic)                 493
# Government (General)                    472
# Police                                  437
# Airports & Aircraft                     179
# Educational Institution                 160
# Journalists & Media                     113
# Terrorists/Non-State Militia            100
# Utilities                                92
# Transportation                           86
# Religious Figures/Institutions           47
# NGO                                      25
# Telecommunication                        22
# Violent Political Party                  21
# Tourists                                 18
# Maritime                                 17
# Unknown                                  15
# Other                                     7
# Food or Water Supply                      5
# Abortion Related                          2

# %%
plt.subplots(figsize=(15,6))
year_counts = df['Target_Type'].value_counts()[:10]
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.title("Types of Target",fontsize= 20)
plt.xlabel('Target_Type',fontsize=20)
plt.xticks(fontsize=15,rotation = 90)
plt.ylabel("No. of Attacks",fontsize=20)
plt.show()

# %%
weapon = pd.DataFrame(df['Weapon_type'].value_counts())
weapon
# Out:
#                                                     Weapon_type
# Explosives                                                 2431
# Firearms                                                   1538
# Incendiary                                                  750
# Unknown                                                     313
# Melee                                                        39
# Chemical                                                     18
# Fake Weapons                                                  2
# Sabotage Equipment                                            1
# Vehicle (not to include vehicle-borne explosive...            1
# Radiological                                                  1
# Other                                                         1

# %%
plt.subplots(figsize=(15,6))
year_counts = df['Weapon_type'].value_counts()[:10]
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.title("Types of weapon",fontsize= 20)
plt.xlabel('Weapon_type',fontsize=20)
plt.xticks(fontsize=11,rotation = 90)
plt.ylabel("No. of Attacks",fontsize=20)
plt.show()

# %%
Group=pd.DataFrame(df["group_name"].value_counts().drop('Unknown'))
Group.head(10)
# Out:
#                                                     group_name
# Irish Republican Army (IRA)                                669
# Protestant extremists                                      184
# Left-Wing Militants                                        169
# Ulster Volunteer Force (UVF)                               159
# Black September                                            120
# Basque Fatherland and Freedom (ETA)                        103
# Ulster Freedom Fighters (UFF)                               90
# Montoneros (Argentina)                                      88
# Black Nationalists                                          82
# Ejercito Revolucionaria del Pueblo (ERP) (Argen...          82

# %%
plt.subplots(figsize=(20,10))
year_counts = df['group_name'].value_counts()[:10]
sns.barplot(x=year_counts.index, y=year_counts.values)
plt.title('group wise Terrorist Attack',fontsize =30)
plt.xlabel("group_name",fontsize =20)
plt.ylabel('No. of Attacks (value_Count)',fontsize =20)
plt.xticks(fontsize=15,rotation = 90)
plt.show()

# %%
gcv=df[["group_name","Country"]].value_counts().drop("Unknown")
gcv.head(20)
# Out:
# <ipython-input-45-8c68947ee2e9>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gcv=df[["group_name","Country"]].value_counts().drop("Unknown")
# group_name                                             Country
# Irish Republican Army (IRA)                            United Kingdom    656
# Protestant extremists                                  United Kingdom    182
# Left-Wing Militants                                    United States     169
# Ulster Volunteer Force (UVF)                           United Kingdom    154
# Basque Fatherland and Freedom (ETA)                    Spain              99
# Montoneros (Argentina)                                 Argentina          88
# Ulster Freedom Fighters (UFF)                          United Kingdom     88
# Ejercito Revolucionaria del Pueblo (ERP) (Argentina)   Argentina          82
# Black Nationalists                                     United States      82
# Fuerzas Armadas de Liberacion Nacional (FALN)          United States      72
# New World Liberation Front (NWLF)                      United States      72
# Student Radicals                                       United States      71
# Irish Republican Extremists                            United Kingdom     59
# Turkish People's Liberation Army                       Turkey             58
# Red Brigades                                           Italy              55
# First of October Antifascist Resistance Group (GRAPO)  Spain              50
# White extremists                                       United States      46
# Revolutionary Patriotic Anti-Fascist Front (FRAP)      Spain              46
# Weather Underground, Weathermen                        United States      45
# Tupamaros (Uruguay)                                    Uruguay            41
# dtype: int64

# %%
gcv.head(10).plot(kind ="bar",figsize=(15,6))
plt.title("Countries with most attacks by an individual Groups",fontsize= 20)
plt.xlabel("(Terrorist Group,Country)",fontsize=20)
plt.xticks(fontsize=12)
plt.ylabel("No. of Attacks",fontsize=20)
plt.show()
